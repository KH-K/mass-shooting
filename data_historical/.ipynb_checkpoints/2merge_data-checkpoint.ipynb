# %%
import pandas as pd
import numpy as np

# %%
dat_14 = pd.read_csv("2014.csv", error_bad_lines=False, index_col=False)

# %%
dat_14.head()
# Out:
#        Incident Date       State  City Or County  \
# 0  December 29, 2014   Louisiana     New Orleans
# 1  December 27, 2014  California     Los Angeles
# 2  December 27, 2014  California      Sacramento
# 3  December 26, 2014    Illinois  East St. Louis
# 4  December 24, 2014    Missouri     Saint Louis
#
#                                Address  # Killed  # Injured  Operations
# 0                  Poydras and Bolivar         0          4         NaN
# 1  8800 block of South Figueroa Street         1          3         NaN
# 2             4000 block of May Street         0          4         NaN
# 3          2500 block of Summit Avenue         1          3         NaN
# 4                        18th and Pine         1          3         NaN

# %%
dat_15 = pd.read_csv("2015.csv", error_bad_lines=False, index_col=False)

# %%
dat_15.head()
# Out:
#        Incident Date         State City Or County  \
# 0  December 31, 2015     Louisiana    New Orleans
# 1  December 27, 2015     Tennessee        Jackson
# 2  December 26, 2015  Pennsylvania   Philadelphia
# 3  December 25, 2015       Florida   Jacksonville
# 4  December 25, 2015       Alabama         Mobile
#
#                        Address  # Killed  # Injured  Operations
# 0  1900 block of Amelia Street         0          6         NaN
# 1                North Parkway         0          4         NaN
# 2           4210 Macalester St         0          4         NaN
# 3          Franklin and Odessa         0          4         NaN
# 4         785 Schillinger Rd S         0          4         NaN

# %%
dat_16 = pd.read_csv("2015.csv", error_bad_lines=False, index_col=False)

# %%
dat_16.head()
# Out:
#        Incident Date         State City Or County  \
# 0  December 31, 2015     Louisiana    New Orleans
# 1  December 27, 2015     Tennessee        Jackson
# 2  December 26, 2015  Pennsylvania   Philadelphia
# 3  December 25, 2015       Florida   Jacksonville
# 4  December 25, 2015       Alabama         Mobile
#
#                        Address  # Killed  # Injured  Operations
# 0  1900 block of Amelia Street         0          6         NaN
# 1                North Parkway         0          4         NaN
# 2           4210 Macalester St         0          4         NaN
# 3          Franklin and Odessa         0          4         NaN
# 4         785 Schillinger Rd S         0          4         NaN

# %%
dat_17 = pd.read_csv("2016.csv", error_bad_lines=False, index_col=False)

# %%
dat_17.head()
# Out:
#        Incident Date        State     City Or County             Address  \
# 0  December 31, 2016      Georgia  Lenox (El Dorado)     27 Briarwood Ct
# 1  December 31, 2016        Texas            Houston  3704 Fannin Street
# 2  December 30, 2016         Ohio          Mansfield  3230 Possum Run Rd
# 3  December 30, 2016  Connecticut        Wallingford    95 S Turnpike Rd
# 4  December 28, 2016      Georgia           Columbus    2914 10th Street
#
#    # Killed  # Injured  Operations
# 0         2          2         NaN
# 1         1          3         NaN
# 2         0          5         NaN
# 3         2          3         NaN
# 4         1          4         NaN

# %%
dat_18 = pd.read_csv("2018.csv", error_bad_lines=False, index_col=False)

# %%
dat_18.head()
# Out:
#        Incident Date      State City Or County            Address  # Killed  \
# 0  December 31, 2018       Ohio      Cleveland   4462 Denison Ave         3
# 1  December 29, 2018       Ohio           Lima      904 S Main St         1
# 2  December 28, 2018   Missouri  Saint Charles   150 Whetstone Dr         4
# 3  December 24, 2018  Louisiana        Lutcher       2176 Main St         2
# 4  December 23, 2018   Missouri    Springfield  1042 W College St         1
#
#    # Injured  Operations
# 0          2         NaN
# 1          3         NaN
# 2          1         NaN
# 3          2         NaN
# 4          6         NaN

# %%
dat_19 = pd.read_csv("2019.csv", error_bad_lines=False, index_col=False)

# %%
dat_19.head()
# Out:
#        Incident Date       State City Or County                     Address  \
# 0  December 29, 2019    Illinois       Danville  1803 block of Westview Ave
# 1  December 29, 2019    New York        Buffalo   50 block of Henrietta Ave
# 2  December 29, 2019  California          Ceres   800 block of Allacante Dr
# 3  December 27, 2019  California        Modesto    1900 block of Vernon Ave
# 4  December 27, 2019     Georgia       Kennesaw       1575 Ridenour Pkwy NW
#
#    # Killed  # Injured  Operations
# 0         0          5         NaN
# 1         1          3         NaN
# 2         0          5         NaN
# 3         1          3         NaN
# 4         0          4         NaN

# %%
#merge all data
dat_14_19 = pd.concat([dat_19, dat_18, dat_17, dat_16, dat_15, dat_14])

# %%
# change first column as date
dat_14_19['Incident Date'] = pd.to_datetime(dat_14_19['Incident Date'])

# %%
dat_14_19.head()
# Out:
#   Incident Date       State City Or County                     Address  \
# 0    2019-12-29    Illinois       Danville  1803 block of Westview Ave
# 1    2019-12-29    New York        Buffalo   50 block of Henrietta Ave
# 2    2019-12-29  California          Ceres   800 block of Allacante Dr
# 3    2019-12-27  California        Modesto    1900 block of Vernon Ave
# 4    2019-12-27     Georgia       Kennesaw       1575 Ridenour Pkwy NW
#
#    # Killed  # Injured  Operations
# 0         0          5         NaN
# 1         1          3         NaN
# 2         0          5         NaN
# 3         1          3         NaN
# 4         0          4         NaN

# %%
# verifying
dat_14_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2076 entries, 0 to 268
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Incident Date   2076 non-null   datetime64[ns]
#  1   State           2076 non-null   object
#  2   City Or County  2076 non-null   object
#  3   Address         2071 non-null   object
#  4   # Killed        2076 non-null   int64
#  5   # Injured       2076 non-null   int64
#  6   Operations      0 non-null      float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 129.8+ KB

# %%
# set as index
dat_14_19.set_index('Incident Date', inplace=False)
# Out:
#                       State City Or County  \
# Incident Date
# 2019-12-29         Illinois       Danville
# 2019-12-29         New York        Buffalo
# 2019-12-29       California          Ceres
# 2019-12-27       California        Modesto
# 2019-12-27          Georgia       Kennesaw
# ...                     ...            ...
# 2014-01-12          Alabama     Huntsville
# 2014-01-11      Mississippi        Jackson
# 2014-01-05     Pennsylvania           Erie
# 2014-01-03         New York         Queens
# 2014-01-01         Virginia        Norfolk
#
#                                                      Address  # Killed  \
# Incident Date
# 2019-12-29                        1803 block of Westview Ave         0
# 2019-12-29                         50 block of Henrietta Ave         1
# 2019-12-29                         800 block of Allacante Dr         0
# 2019-12-27                          1900 block of Vernon Ave         1
# ...

# %%
# I found useless column
del dat_14_19['Operations']

# %%
dat_14_19.head()
# Out:
#   Incident Date       State City Or County                     Address  \
# 0    2019-12-29    Illinois       Danville  1803 block of Westview Ave
# 1    2019-12-29    New York        Buffalo   50 block of Henrietta Ave
# 2    2019-12-29  California          Ceres   800 block of Allacante Dr
# 3    2019-12-27  California        Modesto    1900 block of Vernon Ave
# 4    2019-12-27     Georgia       Kennesaw       1575 Ridenour Pkwy NW
#
#    # Killed  # Injured
# 0         0          5
# 1         1          3
# 2         0          5
# 3         1          3
# 4         0          4

# %%
dat_14_19.to_csv("1419.csv", mode='w')
