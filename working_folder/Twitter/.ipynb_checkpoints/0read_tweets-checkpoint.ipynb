# %%
import json
import pandas as pd
import numpy as np

# %%
tweets = []
for line in open('part-m-00000', 'r'):
    tweets.append(json.loads(line))

# %%
tweets = dict(zip(range(len(tweets)), tweets))

# %%
data1 = pd.DataFrame.from_dict(tweets)

# %%
data1.head()
# Out:
#                                                               0      \
# favorited                                                     False
# text              RT @BladeNeon: #gunviolence #GunReformNow\nI e...
# created_at                           Wed Jul 31 20:04:23 -0400 2019
# user_id_str                                              4144440552
# user_screen_name                                      KageMushaAnon
#
#                                                               1      \
# favorited                                                     False
# text              There have been more mass shootings than days ...
# created_at                           Wed Jul 31 20:20:40 -0400 2019
# user_id_str                                     1016367288017092608
# user_screen_name                                       Defendapack1
#
#                                                               2      \
# favorited                                                     False
# ...

# %%
data1 = np.transpose(data1)
data1.head()
# Out:
#   favorited                                               text  \
# 0     False  RT @BladeNeon: #gunviolence #GunReformNow\nI e...
# 1     False  There have been more mass shootings than days ...
# 2     False  RT @Defendapack1: There have been more mass sh...
# 3     False  RT @PasReport: 🎙This week’s #podcast episode f...
# 4     False  @SenToomey tells #Pennsylvania to go to hell w...
#
#                        created_at          user_id_str user_screen_name  \
# 0  Wed Jul 31 20:04:23 -0400 2019           4144440552    KageMushaAnon
# 1  Wed Jul 31 20:20:40 -0400 2019  1016367288017092608     Defendapack1
# 2  Wed Jul 31 20:43:19 -0400 2019           2757914776     CallingUOut4
# 3  Wed Jul 31 21:00:26 -0400 2019           2875700829     AmericAnon57
# 4  Wed Jul 31 21:27:08 -0400 2019   974241878399901697      SaneGunLaws
#
#   retweet_count retweeted retweeted_status_id_str  \
# 0             0     False     1156705469060153344
# ...

# %%
print(data1['text'][5])
# Out:
# RT @ScotLithVAian: 🎙️In this wks @pasreport ep.,💥Prof. Giordano focuses on #GunViolence. Is it a #Gun problem vs a #cultural problem. #MSM-…
